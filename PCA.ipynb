# %% [markdown]
# <a href="https://colab.research.google.com/github/DarshanYG/Machine-Learning-Lab-5th-Sem/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

data = datasets.load_iris()
X = data.data

X = StandardScaler().fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

print("Original Shape:", X.shape)
print("Reduced Shape:", X_pca.shape)
print("Explained Variance:", pca.explained_variance_ratio_)
print(X_pca[:5])
# Out:
# Original Shape: (150, 4)
# Reduced Shape: (150, 2)
# Explained Variance: [0.72962445 0.22850762]
# [[-2.26470281  0.4800266 ]
#  [-2.08096115 -0.67413356]
#  [-2.36422905 -0.34190802]
#  [-2.29938422 -0.59739451]
#  [-2.38984217  0.64683538]]

# %%
# Useful for viva: compare models quickly
from sklearn.metrics import accuracy_score
print("Use accuracy_score, confusion_matrix, r2_score depending on task")
# Out:
# Use accuracy_score, confusion_matrix, r2_score depending on task
